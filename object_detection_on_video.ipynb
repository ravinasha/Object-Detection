# %%
import numpy as np
import cv2
import time

def main():
    # Define video file paths
    input_video_path = '/content/traffic_4.mp4'
    output_video_path = '/content/output traffic-cars.mp4'

    # Load YOLO
    labels, network, layers_names_output = load_yolo()

    # Open video file
    video = cv2.VideoCapture(input_video_path)
    if not video.isOpened():
        print("Error: Could not open video.")
        return

    # Prepare video writer
    writer = None
    h, w = None, None

    # Processing loop
    frame_count = 0
    total_time = 0
    while True:
        ret, frame = video.read()
        if not ret:
            break

        if w is None or h is None:
            h, w = frame.shape[:2]

        blob = cv2.dnn.blobFromImage(frame, 1 / 255.0, (416, 416), swapRB=True, crop=False)
        network.setInput(blob)
        start_time = time.time()
        output_from_network = network.forward(layers_names_output)
        end_time = time.time()

        frame_count += 1
        total_time += end_time - start_time
        print(f'Frame {frame_count} took {end_time - start_time:.5f} seconds')

        bounding_boxes, confidences, classIDs = process_detections(output_from_network, frame.shape[1], frame.shape[0])

        results = cv2.dnn.NMSBoxes(bounding_boxes, confidences, 0.5, 0.3)

        if len(results) > 0:
            for i in results.flatten():
                x_min, y_min = bounding_boxes[i][0], bounding_boxes[i][1]
                box_width, box_height = bounding_boxes[i][2], bounding_boxes[i][3]
                color = colours[classIDs[i]].tolist()

                cv2.rectangle(frame, (x_min, y_min), (x_min + box_width, y_min + box_height), color, 2)
                text = f'{labels[classIDs[i]]}: {confidences[i]:.4f}'
                cv2.putText(frame, text, (x_min, y_min - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

        if writer is None:
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            writer = cv2.VideoWriter(output_video_path, fourcc, 30, (frame.shape[1], frame.shape[0]), True)

        writer.write(frame)

    video.release()
    writer.release()

    print(f'\nTotal number of frames: {frame_count}')
    print(f'Total amount of time: {total_time:.5f} seconds')
    print(f'FPS: {frame_count / total_time:.1f}')

def load_yolo():
    labels_path = '/content/coco.names'
    config_path = '/content/yolov3-tiny.cfg'
    weights_path = '/content/yolov3-tiny.weights'

    with open(labels_path) as f:
        labels = [line.strip() for line in f]

    network = cv2.dnn.readNetFromDarknet(config_path, weights_path)
    layers_names_all = network.getLayerNames()
    out_layers = network.getUnconnectedOutLayers()

    if isinstance(out_layers, np.ndarray):
        layers_names_output = [layers_names_all[i - 1] for i in out_layers.flatten()]
    else:
        layers_names_output = [layers_names_all[i[0] - 1] for i in out_layers]

    global colours
    colours = np.random.randint(0, 255, size=(len(labels), 3), dtype='uint8')

    return labels, network, layers_names_output

def process_detections(output_from_network, frame_width, frame_height):
    bounding_boxes = []
    confidences = []
    classIDs = []

    for result in output_from_network:
        for detected_objects in result:
            scores = detected_objects[5:]
            class_current = np.argmax(scores)
            confidence_current = scores[class_current]

            if confidence_current > 0.5:
                box_current = detected_objects[0:4] * np.array([frame_width, frame_height, frame_width, frame_height])
                x_center, y_center, box_width, box_height = box_current
                x_min = int(x_center - (box_width / 2))
                y_min = int(y_center - (box_height / 2))

                bounding_boxes.append([x_min, y_min, int(box_width), int(box_height)])
                confidences.append(float(confidence_current))
                classIDs.append(class_current)

    return bounding_boxes, confidences, classIDs

if __name__ == "__main__":
    main()
# Out:
# Frame 1 took 0.40904 seconds
# Frame 2 took 0.09751 seconds
# Frame 3 took 0.13250 seconds
# Frame 4 took 0.12491 seconds
# Frame 5 took 0.10900 seconds
# Frame 6 took 0.10077 seconds
# Frame 7 took 0.10190 seconds
# Frame 8 took 0.09563 seconds
# Frame 9 took 0.12914 seconds
# Frame 10 took 0.09959 seconds
# Frame 11 took 0.10277 seconds
# Frame 12 took 0.12024 seconds
# Frame 13 took 0.10394 seconds
# Frame 14 took 0.10475 seconds
# Frame 15 took 0.10357 seconds
# Frame 16 took 0.11025 seconds
# Frame 17 took 0.10882 seconds
# Frame 18 took 0.10075 seconds
# Frame 19 took 0.10642 seconds
# Frame 20 took 0.12835 seconds
# Frame 21 took 0.10915 seconds
# Frame 22 took 0.09920 seconds
# Frame 23 took 0.11644 seconds
# Frame 24 took 0.09796 seconds
# Frame 25 took 0.10200 seconds
# Frame 26 took 0.10843 seconds
# Frame 27 took 0.12954 seconds
# Frame 28 took 0.09614 seconds
# Frame 29 took 0.09947 seconds
# Frame 30 took 0.10672 seconds
# Frame 31 took 0.11533 seconds
# Frame 32 took 0.09521 seconds
# Frame 33 took 0.10446 seconds
# Frame 34 took 0.09442 seconds
# Frame 35 took 0.12831 seconds
# Frame 36 took 0.10671 seconds
# Frame 37 took 0.10554 seconds
# Frame 38 took 0.11108 seconds
# Frame 39 took 0.14592 seconds
# Frame 40 took 0.16227 seconds
# Frame 41 took 0.18890 seconds
# Frame 42 took 0.16036 seconds
# Frame 43 took 0.18318 seconds
# Frame 44 took 0.18541 seconds
# Frame 45 took 0.16939 seconds
# Frame 46 took 0.17676 seconds
# Frame 47 took 0.17382 seconds
# Frame 48 took 0.18630 seconds
# Frame 49 took 0.17491 seconds
# Frame 50 took 0.17113 seconds
# Frame 51 took 0.17288 seconds
# Frame 52 took 0.18106 seconds
# Frame 53 took 0.17602 seconds
# Frame 54 took 0.17769 seconds
# Frame 55 took 0.14794 seconds
# Frame 56 took 0.09381 seconds
# Frame 57 took 0.10456 seconds
# Frame 58 took 0.11032 seconds
# Frame 59 took 0.10201 seconds
# Frame 60 took 0.09996 seconds
# Frame 61 took 0.10016 seconds
# Frame 62 took 0.10536 seconds
# Frame 63 took 0.10250 seconds
# Frame 64 took 0.11501 seconds
# Frame 65 took 0.10006 seconds
# Frame 66 took 0.11144 seconds
# Frame 67 took 0.10355 seconds
# Frame 68 took 0.10966 seconds
# Frame 69 took 0.09738 seconds
# Frame 70 took 0.11290 seconds
# Frame 71 took 0.09920 seconds
# Frame 72 took 0.11624 seconds
# Frame 73 took 0.11280 seconds
# Frame 74 took 0.12602 seconds
# Frame 75 took 0.09564 seconds
# Frame 76 took 0.10807 seconds
# Frame 77 took 0.10794 seconds
# Frame 78 took 0.10194 seconds
# Frame 79 took 0.10069 seconds
# Frame 80 took 0.12078 seconds
# Frame 81 took 0.11122 seconds
# Frame 82 took 0.10274 seconds
# Frame 83 took 0.10274 seconds
# Frame 84 took 0.10793 seconds
# Frame 85 took 0.10211 seconds
# Frame 86 took 0.09816 seconds
# Frame 87 took 0.11028 seconds
# Frame 88 took 0.10867 seconds
# Frame 89 took 0.10163 seconds
# Frame 90 took 0.10814 seconds
# Frame 91 took 0.09622 seconds
# Frame 92 took 0.10740 seconds
# Frame 93 took 0.09831 seconds
# Frame 94 took 0.10397 seconds
# Frame 95 took 0.10733 seconds
# Frame 96 took 0.10839 seconds
# Frame 97 took 0.10761 seconds
# Frame 98 took 0.10576 seconds
# Frame 99 took 0.09710 seconds
# Frame 100 took 0.11228 seconds
# Frame 101 took 0.09734 seconds
# Frame 102 took 0.10850 seconds
# Frame 103 took 0.12157 seconds
# Frame 104 took 0.10768 seconds
# Frame 105 took 0.09630 seconds
# Frame 106 took 0.10692 seconds
# Frame 107 took 0.11111 seconds
# Frame 108 took 0.10660 seconds
# Frame 109 took 0.09588 seconds
# Frame 110 took 0.10253 seconds
# Frame 111 took 0.12272 seconds
# Frame 112 took 0.10377 seconds
# Frame 113 took 0.10052 seconds
# Frame 114 took 0.10517 seconds
# Frame 115 took 0.10089 seconds
# Frame 116 took 0.10970 seconds
# Frame 117 took 0.09683 seconds
# Frame 118 took 0.10216 seconds
# Frame 119 took 0.12031 seconds
# Frame 120 took 0.10682 seconds
# Frame 121 took 0.10459 seconds
# Frame 122 took 0.10062 seconds
# Frame 123 took 0.10060 seconds
# Frame 124 took 0.10268 seconds
# Frame 125 took 0.10077 seconds
# Frame 126 took 0.11471 seconds
# Frame 127 took 0.11124 seconds
# Frame 128 took 0.10098 seconds
# Frame 129 took 0.09630 seconds
# Frame 130 took 0.10807 seconds
# Frame 131 took 0.15520 seconds
# Frame 132 took 0.16581 seconds
# Frame 133 took 0.16768 seconds
# Frame 134 took 0.16457 seconds
# Frame 135 took 0.16304 seconds
# Frame 136 took 0.16549 seconds
# Frame 137 took 0.16901 seconds
# Frame 138 took 0.16722 seconds
# Frame 139 took 0.16966 seconds
# Frame 140 took 0.17426 seconds
# Frame 141 took 0.16256 seconds
# Frame 142 took 0.19189 seconds
# Frame 143 took 0.18311 seconds
# Frame 144 took 0.18043 seconds
# Frame 145 took 0.18299 seconds
# Frame 146 took 0.18000 seconds
# Frame 147 took 0.11270 seconds
# Frame 148 took 0.10911 seconds
# Frame 149 took 0.11602 seconds
# Frame 150 took 0.12097 seconds
# Frame 151 took 0.09759 seconds
# Frame 152 took 0.10308 seconds
# Frame 153 took 0.09690 seconds
# Frame 154 took 0.11262 seconds
# Frame 155 took 0.10015 seconds
# Frame 156 took 0.10434 seconds
# Frame 157 took 0.10217 seconds
# Frame 158 took 0.10855 seconds
# Frame 159 took 0.10271 seconds
# Frame 160 took 0.10499 seconds
# Frame 161 took 0.10549 seconds
# Frame 162 took 0.11946 seconds
# Frame 163 took 0.10384 seconds
# Frame 164 took 0.11579 seconds
# Frame 165 took 0.10668 seconds
# Frame 166 took 0.10284 seconds
# Frame 167 took 0.10747 seconds
# Frame 168 took 0.10719 seconds
# Frame 169 took 0.10695 seconds
# Frame 170 took 0.09834 seconds
# Frame 171 took 0.09900 seconds
# Frame 172 took 0.12475 seconds
# Frame 173 took 0.10053 seconds
# Frame 174 took 0.10391 seconds
# Frame 175 took 0.11001 seconds
# Frame 176 took 0.10656 seconds
# Frame 177 took 0.10697 seconds
# Frame 178 took 0.10943 seconds
# Frame 179 took 0.09870 seconds
# Frame 180 took 0.12500 seconds
# Frame 181 took 0.09841 seconds
# Frame 182 took 0.11527 seconds
# Frame 183 took 0.09899 seconds
# Frame 184 took 0.11488 seconds
# Frame 185 took 0.10109 seconds
# Frame 186 took 0.10835 seconds
# Frame 187 took 0.09940 seconds
# Frame 188 took 0.12432 seconds
# Frame 189 took 0.10219 seconds
# Frame 190 took 0.10497 seconds
# Frame 191 took 0.09745 seconds
# Frame 192 took 0.11216 seconds
# Frame 193 took 0.09886 seconds
# Frame 194 took 0.10564 seconds
# Frame 195 took 0.09954 seconds
# Frame 196 took 0.11837 seconds
# Frame 197 took 0.10051 seconds
# Frame 198 took 0.11439 seconds
# Frame 199 took 0.11061 seconds
# Frame 200 took 0.10000 seconds
# Frame 201 took 0.10181 seconds
# Frame 202 took 0.11179 seconds
# Frame 203 took 0.11845 seconds
# Frame 204 took 0.10171 seconds
# Frame 205 took 0.09637 seconds
# Frame 206 took 0.10855 seconds
# Frame 207 took 0.10589 seconds
# Frame 208 took 0.10504 seconds
# Frame 209 took 0.10069 seconds
# Frame 210 took 0.10120 seconds
# Frame 211 took 0.11485 seconds
# Frame 212 took 0.10557 seconds
# Frame 213 took 0.10471 seconds
# Frame 214 took 0.11119 seconds
# Frame 215 took 0.09960 seconds
# Frame 216 took 0.10612 seconds
# Frame 217 took 0.10692 seconds
# Frame 218 took 0.10324 seconds
# Frame 219 took 0.11149 seconds
# Frame 220 took 0.10881 seconds
# Frame 221 took 0.09655 seconds
# Frame 222 took 0.13464 seconds
# Frame 223 took 0.16385 seconds
# Frame 224 took 0.17374 seconds
# Frame 225 took 0.18085 seconds
# Frame 226 took 0.19250 seconds
# Frame 227 took 0.17271 seconds
# Frame 228 took 0.17068 seconds
# Frame 229 took 0.16698 seconds
# Frame 230 took 0.17984 seconds
# Frame 231 took 0.17723 seconds
# Frame 232 took 0.15623 seconds
# Frame 233 took 0.17103 seconds
# Frame 234 took 0.16773 seconds
# Frame 235 took 0.18774 seconds
# Frame 236 took 0.18500 seconds
# Frame 237 took 0.17838 seconds
# Frame 238 took 0.14199 seconds
# Frame 239 took 0.10400 seconds
# Frame 240 took 0.10522 seconds
# Frame 241 took 0.12749 seconds
# Frame 242 took 0.10894 seconds
# Frame 243 took 0.11235 seconds
# Frame 244 took 0.13228 seconds
# Frame 245 took 0.09963 seconds
# Frame 246 took 0.09608 seconds
# Frame 247 took 0.10269 seconds
# Frame 248 took 0.10493 seconds
# Frame 249 took 0.11766 seconds
# Frame 250 took 0.10312 seconds
# Frame 251 took 0.11024 seconds
# Frame 252 took 0.09786 seconds
# Frame 253 took 0.10662 seconds
# Frame 254 took 0.09752 seconds
# Frame 255 took 0.11733 seconds
# Frame 256 took 0.11185 seconds
# Frame 257 took 0.10816 seconds
# Frame 258 took 0.10173 seconds
# Frame 259 took 0.10561 seconds
# Frame 260 took 0.09895 seconds
# Frame 261 took 0.11153 seconds
# Frame 262 took 0.10682 seconds
# Frame 263 took 0.10476 seconds
# Frame 264 took 0.12550 seconds
# Frame 265 took 0.11513 seconds
# Frame 266 took 0.09652 seconds
# Frame 267 took 0.10232 seconds
# Frame 268 took 0.10404 seconds
# Frame 269 took 0.10501 seconds
# Frame 270 took 0.09868 seconds
# Frame 271 took 0.10410 seconds
# Frame 272 took 0.10949 seconds
# Frame 273 took 0.10630 seconds
# Frame 274 took 0.09859 seconds
# Frame 275 took 0.10914 seconds
# Frame 276 took 0.09535 seconds
# Frame 277 took 0.09791 seconds
# Frame 278 took 0.11018 seconds
# Frame 279 took 0.10839 seconds
# Frame 280 took 0.09930 seconds
# Frame 281 took 0.10856 seconds
# Frame 282 took 0.10464 seconds
# Frame 283 took 0.10485 seconds
# Frame 284 took 0.10256 seconds
# Frame 285 took 0.11274 seconds
# Frame 286 took 0.09747 seconds
# Frame 287 took 0.12104 seconds
# Frame 288 took 0.10981 seconds
# Frame 289 took 0.10292 seconds
# Frame 290 took 0.09731 seconds
# Frame 291 took 0.10259 seconds
# Frame 292 took 0.10116 seconds
# Frame 293 took 0.10328 seconds
# Frame 294 took 0.10173 seconds
# Frame 295 took 0.12570 seconds
# Frame 296 took 0.09942 seconds
# Frame 297 took 0.10160 seconds
# Frame 298 took 0.10617 seconds
# Frame 299 took 0.09970 seconds
# Frame 300 took 0.09697 seconds
# Frame 301 took 0.10521 seconds
# Frame 302 took 0.12256 seconds
# Frame 303 took 0.11952 seconds
# Frame 304 took 0.09879 seconds
# Frame 305 took 0.10618 seconds
# Frame 306 took 0.10450 seconds
# Frame 307 took 0.10447 seconds
# Frame 308 took 0.11115 seconds
# Frame 309 took 0.11174 seconds
# Frame 310 took 0.09889 seconds
# Frame 311 took 0.11916 seconds
# Frame 312 took 0.11704 seconds
# Frame 313 took 0.15661 seconds
# Frame 314 took 0.16899 seconds
# Frame 315 took 0.17661 seconds
# Frame 316 took 0.18404 seconds
# Frame 317 took 0.15907 seconds
# Frame 318 took 0.17242 seconds
# Frame 319 took 0.16422 seconds
# Frame 320 took 0.17329 seconds
# Frame 321 took 0.18171 seconds
# Frame 322 took 0.18381 seconds
# Frame 323 took 0.15826 seconds
# Frame 324 took 0.17231 seconds
# Frame 325 took 0.18102 seconds
# Frame 326 took 0.17849 seconds
# Frame 327 took 0.16752 seconds
# Frame 328 took 0.15987 seconds
# Frame 329 took 0.10745 seconds
# Frame 330 took 0.10933 seconds
# Frame 331 took 0.10640 seconds
# Frame 332 took 0.09667 seconds
# Frame 333 took 0.11695 seconds
# Frame 334 took 0.10019 seconds
# Frame 335 took 0.10388 seconds
# Frame 336 took 0.10226 seconds
# Frame 337 took 0.10566 seconds
# Frame 338 took 0.09637 seconds
# Frame 339 took 0.10300 seconds
# Frame 340 took 0.11054 seconds
# Frame 341 took 0.12418 seconds
# Frame 342 took 0.09627 seconds
# Frame 343 took 0.10452 seconds
# Frame 344 took 0.10552 seconds
# Frame 345 took 0.10760 seconds
# Frame 346 took 0.10233 seconds
# Frame 347 took 0.10477 seconds
# Frame 348 took 0.10298 seconds
# Frame 349 took 0.11866 seconds
# Frame 350 took 0.09878 seconds
# Frame 351 took 0.09982 seconds
# Frame 352 took 0.11163 seconds
# Frame 353 took 0.10553 seconds
# Frame 354 took 0.10590 seconds
# Frame 355 took 0.10214 seconds
# Frame 356 took 0.10666 seconds
# Frame 357 took 0.10437 seconds
# Frame 358 took 0.10980 seconds
# Frame 359 took 0.10333 seconds
# Frame 360 took 0.10812 seconds
# Frame 361 took 0.10449 seconds
# Frame 362 took 0.10400 seconds
# Frame 363 took 0.11133 seconds
# Frame 364 took 0.11267 seconds
# Frame 365 took 0.10140 seconds
# Frame 366 took 0.10676 seconds
# Frame 367 took 0.10638 seconds
# Frame 368 took 0.11180 seconds
# Frame 369 took 0.10630 seconds
# Frame 370 took 0.09827 seconds
# Frame 371 took 0.09901 seconds
# Frame 372 took 0.11519 seconds
#
# Total number of frames: 372
# Total amount of time: 44.20679 seconds
# FPS: 8.4

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Load YOLO
net = cv2.dnn.readNet('/content/yolov3-tiny.weights', '/content/yolov3-tiny.cfg')
layer_names = net.getLayerNames()
output_layers_indices = net.getUnconnectedOutLayers()

# Handle layer indices
output_layers = [layer_names[i - 1] for i in output_layers_indices.flatten()]

# Load video file
input_video_path = '/content/traffic_4.mp4'
output_video_path = '/content/output_video.mp4'
cap = cv2.VideoCapture(input_video_path)

# Get video properties
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
fps = int(cap.get(cv2.CAP_PROP_FPS))
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Initialize VideoWriter
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

# Check type of `out`
print(f'Type of out before processing: {type(out)}')

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Prepare the frame for YOLO
    height, width, channels = frame.shape
    blob = cv2.dnn.blobFromImage(frame, 0.00392, (416, 416), (0, 0, 0), True, crop=False)
    net.setInput(blob)
    outs = net.forward(output_layers)

    # Process YOLO outputs
    class_ids = []
    confidences = []
    boxes = []

    for out in outs:
        for detection in out:
            if detection.ndim == 2:  # Ensure detection is 2D
                for obj in detection:
                    if obj.size >= 85:  # YOLOv3 output size
                        scores = obj[5:]
                        class_id = np.argmax(scores)
                        confidence = scores[class_id]
                        if confidence > 0.5:
                            center_x = int(obj[0] * width)
                            center_y = int(obj[1] * height)
                            w = int(obj[2] * width)
                            h = int(obj[3] * height)
                            x = int(center_x - w / 2)
                            y = int(center_y - h / 2)
                            boxes.append([x, y, w, h])
                            confidences.append(float(confidence))
                            class_ids.append(class_id)

    # Apply non-max suppression to remove duplicate boxes
    indices = cv2.dnn.NMSBoxes(boxes, confidences, 0.5, 0.4)
    if len(indices) > 0:
        for i in indices.flatten():
            box = boxes[i]
            x, y, w, h = box
            label = str(class_ids[i])
            confidence = confidences[i]
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
            cv2.putText(frame, f'{label} {confidence:.2f}', (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        out.write(frame)

# Check type of `out` before releasing
print(f'Type of out before releasing: {type(out)}')

# Release the capture and writer properly
# Out:
# Type of out before processing: <class 'cv2.VideoWriter'>
# Type of out before releasing: <class 'numpy.ndarray'>

# %%
import cv2

# Initialize VideoCapture and VideoWriter
cap = cv2.VideoCapture('/content/traffic_4.mp4')
out = cv2.VideoWriter('/content/output_video.mp4', cv2.VideoWriter_fourcc(*'mp4v'), 20.0, (640, 480))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    # Process the frame (e.g., write it to the output video)
    out.write(frame)

# Release the VideoCapture and VideoWriter objects
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
output_cap = cv2.VideoCapture(output_video_path)
for _ in range(10):  # Display the first 10 frames
    ret, frame = output_cap.read()
    if not ret:
        break
    cv2_imshow(frame)

output_cap.release()
